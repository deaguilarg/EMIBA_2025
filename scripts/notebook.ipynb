# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/vn55ysp/Downloads/police_deaths_USA_v6.csv")

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
git pull: Me traigo todo lo que hay en la rama.

aca trabajas. o hago como que trabajo

git add: Acá selecciono lo que quiero subir a la rama y que los demás puedan verlo.
git commit -m. Acá escribo lo que hice, para que los demás entiendan y sepan q hice.
git push. Acá envío todo hacia la nube.
